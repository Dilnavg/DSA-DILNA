# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('C:\DSA\StudentsPerformance_2.csv')

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
data.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %% [markdown]
#     ###ANSWER 1:MALES AND FEMALES PRESENT ON THE TEST

# %%
data.gender.value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
    ###ANSWER 2:students' parental level of education

# %%
data['parental level of education'].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %%
data['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
    ##INSIGHTS:Out of 1000 students data 226 students have their parents acquire some college level education.
    ##Only 59 students parents have masters degree

# %%
plt.figure(figsize= (10,6))
sns.countplot(data['parental level of education'])
plt.title('students parental level of education')
plt.xticks(rotation=90)
plt.ylabel('Number of students')
# Out:
# C:\Users\DILNA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Number of students')

# %%
plt.figure(figsize= (10,6))
data['Total Score']=data['math score']+data['reading score']+data['writing score']
plt.title("Total Score v/s parental level of education")
sns.barplot(x=data['parental level of education'],y=data['Total Score'])
# Out:
# <AxesSubplot:title={'center':'Total Score v/s parental level of education'}, xlabel='parental level of education', ylabel='Total Score'>

# %%
    ### Students having parents  with  masters degree or bachelors degree improves the total score in students perfomance.
    #Parents with The high school background showing less total score than others with masters or bachelors

# %%
##ANSWER 3:AVERAGE ON MATHS

# %%
fig,ax = plt.subplots(3,1, figsize = (5,10))
sns.boxplot(x=data['gender'],y=data['math score'],ax=ax[0])
sns.boxplot(x=data['gender'],y=data['reading score'],ax=ax[1])
sns.boxplot(x=data['gender'],y=data['writing score'],ax=ax[2])
plt.tight_layout()

# %%
data.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score', 'Total Score'],
#       dtype='object')

# %%
fig,ax = plt.subplots(3,1, figsize = (5,10))
sns.boxplot(x=data['test preparation course'],y=data['math score'],ax=ax[0])
sns.boxplot(x=data['test preparation course'],y=data['reading score'],ax=ax[1])
sns.boxplot(x=data['test preparation course'],y=data['writing score'],ax=ax[2])
plt.tight_layout()

# %%
data.groupby(['gender','math score','reading score','writing score']).sum()
# Out:
#                                                Total Score
# gender math score reading score writing score
# female 0          17            10                      27
#        8          24            23                      55
#        18         32            28                      78
#        19         38            32                      89
#        22         39            33                      94
# ...                                                    ...
# male   99         87            81                     267
#        100        96            86                     282
#                   97            99                     296
#                   100           93                     293
#                                 100                    300
#
# [985 rows x 1 columns]

# %% [markdown]
# ####ANSWER:4-SCORING VARIATION BASED ON GENDER & TEST PREPARATION COURSE

# %%
plt.figure(figsize=(6,5))
sns.barplot(x=data['test preparation course'],y=data['Total Score'])
plt.title("Total Score variation of  test prep course")
# Out:
# Text(0.5, 1.0, 'Total Score variation of  test prep course')

# %%
plt.figure(figsize=(6,5))
sns.barplot(x=data['gender'],y=data['Total Score'])
plt.title("Total Score variation of gender")
# Out:
# Text(0.5, 1.0, 'Total Score variation of gender')
